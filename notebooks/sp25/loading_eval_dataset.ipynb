# %%
import pickle
    
eval_dataset_path = "/home/mc76728/repo/Coargus/vrag/generator_eval_dataset.pkl"
# Read the results back from the pickle file for testing
with open(eval_dataset_path, "rb") as f:
    loaded_results = pickle.load(f)

sample = loaded_results[0:5]
for result in sample:
    print(result)
    print("-" * 35 + "\n")
# Out:
# {'question': 'According to the lecture, what specific mathematical areas are fundamental to the technical tools used in this machine learning course?', 'answer': 'The lecture specifies that linear algebra, probability, multivariate statistics, and optimization are fundamental mathematical areas for the technical tools used in the machine learning course. While not requiring expertise in all these areas, a decent background in linear algebra is a prerequisite, and other material will be covered in class.'}
# -----------------------------------
#
# {'question': 'According to the lecture, what specific topics involving mathematics, namely Calculus and Linear Algebra, will be used as the basis for getting into classical least squares regression?', 'answer': 'The lecture mentions that as the course gets into classical least squares regression, it will require some mathematics involving multi-weighted calculus and linear algebra. This motivates a linear algebra review later in the course.'}
# -----------------------------------
#
# {'question': 'According to the lecture, what cornerstone method in linear algebra will be discussed in relation to regression, and what regularization technique will be explored alongside it?', 'answer': 'The lecture mentions that Singular Value Decomposition (SVD) will be discussed as a cornerstone method in linear algebra, specifically in relation to regression. Furthermore, Ridge Regression is mentioned as a regularization technique that will be explored alongside it in the context of classical regression.'}
# -----------------------------------
#
# {'question': 'Based on the student introductions, what specific area within Data Science, which itself falls under the broader field of Machine Learning, does Atharva indicate he is currently working in?', 'answer': 'Atharva mentions that he is working in the data science area, and more specifically, doing some NLP (Natural Language Processing) work.'}
# -----------------------------------
#
# {'question': 'Based on the introductions, name one student whose project involves the application of computer vision and what field they are applying it to.', 'answer': 'Mir Mohammad Shamszadeh, a PhD student in civil engineering, is working on a project involving the application of computer vision to structural monitoring of bridges.'}
# -----------------------------------
